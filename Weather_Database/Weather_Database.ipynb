# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
import gmaps

from citipy import citipy
from config import weather_api_key
from config import g_key

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# 4. Get the nearest city using the citipy module.

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
    
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
     # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# 5. Perform an API call with the OpenWeatherMap.
# 6. Retrieve the following information from the API call.

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_name = city
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city_name,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avigliana
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | muros
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | bubaque
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | cairns
# Processing Record 11 of Set 1 | acajutla
# Processing Record 12 of Set 1 | faanui
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | bathsheba
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | dobsina
# Processing Record 22 of Set 1 | saldanha
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | dunmore town
# Processing Record 25 of Set 1 | port moresby
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | lahad datu
# Processing Record 28 of Set 1 | guerrero negro
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | guangyuan
# Processing Record 32 of Set 1 | beawar
# Processing Record 33 of Set 1 | parainen
# Processing Record 34 of Set 1 | tautira
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | pousat
# City not found. Skipping...
# Processing Record 37 of Set 1 | puerto escondido
# Processing Record 38 of Set 1 | muisne
# Processing Record 39 of Set 1 | sancti spiritus
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | soledade
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | alyangula
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | nha trang
# Processing Record 46 of Set 1 | oksfjord
# Processing Record 47 of Set 1 | sabha
# Processing Record 48 of Set 1 | rio cuarto
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | clarence town
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | alashtar
# City not found. Skipping...
# Processing Record 3 of Set 2 | te anau
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | praia da vitoria
# Processing Record 8 of Set 2 | ilhabela
# Processing Record 9 of Set 2 | worthington
# Processing Record 10 of Set 2 | ulcinj
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | kutoarjo
# Processing Record 13 of Set 2 | abu dhabi
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | acapulco
# Processing Record 16 of Set 2 | port-gentil
# Processing Record 17 of Set 2 | acari
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | hay river
# Processing Record 20 of Set 2 | provideniya
# Processing Record 21 of Set 2 | sterling
# Processing Record 22 of Set 2 | fort-shevchenko
# Processing Record 23 of Set 2 | hanmer springs
# Processing Record 24 of Set 2 | ikon-khalk
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | horta
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | egvekinot
# Processing Record 29 of Set 2 | asyut
# Processing Record 30 of Set 2 | caravelas
# Processing Record 31 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 2 | lompoc
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | ucluelet
# Processing Record 35 of Set 2 | lae
# Processing Record 36 of Set 2 | constitucion
# Processing Record 37 of Set 2 | tateyama
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | shenjiamen
# Processing Record 40 of Set 2 | husavik
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 2 | lorengau
# Processing Record 44 of Set 2 | khormuj
# City not found. Skipping...
# Processing Record 45 of Set 2 | vila franca do campo
# Processing Record 46 of Set 2 | severnoye
# Processing Record 47 of Set 2 | ponnani
# Processing Record 48 of Set 2 | nantucket
# Processing Record 49 of Set 2 | dianopolis
# City not found. Skipping...
# Processing Record 50 of Set 2 | salamiyah
# Processing Record 1 of Set 3 | warrnambool
# Processing Record 2 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | bengkulu
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 3 | itapirapua
# Processing Record 11 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 3 | andradas
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | upernavik
# Processing Record 16 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 3 | sola
# Processing Record 18 of Set 3 | atuona
# Processing Record 19 of Set 3 | vostok
# Processing Record 20 of Set 3 | krasnorechenskiy
# Processing Record 21 of Set 3 | port hardy
# Processing Record 22 of Set 3 | kouroussa
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | jamestown
# Processing Record 25 of Set 3 | nalut
# Processing Record 26 of Set 3 | rodrigues alves
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | fairbanks
# Processing Record 29 of Set 3 | marv dasht
# City not found. Skipping...
# Processing Record 30 of Set 3 | eyl
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | hurup
# Processing Record 33 of Set 3 | moree
# Processing Record 34 of Set 3 | flinders
# Processing Record 35 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | los llanos de aridane
# Processing Record 39 of Set 3 | half moon bay
# Processing Record 40 of Set 3 | vanimo
# Processing Record 41 of Set 3 | antofagasta
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | loanda
# Processing Record 44 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 45 of Set 3 | san juan
# Processing Record 46 of Set 3 | hirara
# Processing Record 47 of Set 3 | yamada
# Processing Record 48 of Set 3 | sitka
# Processing Record 49 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 50 of Set 3 | bluff
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | buin
# Processing Record 3 of Set 4 | aksu
# Processing Record 4 of Set 4 | el wasta
# City not found. Skipping...
# Processing Record 5 of Set 4 | aklavik
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 4 | leeton
# Processing Record 9 of Set 4 | tianmen
# Processing Record 10 of Set 4 | youghal
# Processing Record 11 of Set 4 | olafsvik
# Processing Record 12 of Set 4 | svetlogorsk
# Processing Record 13 of Set 4 | bosaso
# Processing Record 14 of Set 4 | esperance
# Processing Record 15 of Set 4 | shetpe
# Processing Record 16 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 4 | alice springs
# Processing Record 18 of Set 4 | ulaanbaatar
# Processing Record 19 of Set 4 | medicine hat
# Processing Record 20 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 4 | kloulklubed
# Processing Record 22 of Set 4 | buala
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | kavieng
# Processing Record 25 of Set 4 | atar
# Processing Record 26 of Set 4 | mount isa
# Processing Record 27 of Set 4 | tiksi
# Processing Record 28 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 4 | takoradi
# Processing Record 30 of Set 4 | westport
# Processing Record 31 of Set 4 | east london
# Processing Record 32 of Set 4 | pontianak
# Processing Record 33 of Set 4 | tynda
# Processing Record 34 of Set 4 | pahrump
# Processing Record 35 of Set 4 | paducah
# Processing Record 36 of Set 4 | hamina
# Processing Record 37 of Set 4 | seydi
# Processing Record 38 of Set 4 | port alfred
# Processing Record 39 of Set 4 | xam nua
# Processing Record 40 of Set 4 | havre-saint-pierre
# Processing Record 41 of Set 4 | deder
# Processing Record 42 of Set 4 | sakakah
# Processing Record 43 of Set 4 | hofn
# Processing Record 44 of Set 4 | ixtapa
# Processing Record 45 of Set 4 | smithers
# Processing Record 46 of Set 4 | bodden town
# Processing Record 47 of Set 4 | stephenville
# Processing Record 48 of Set 4 | dikson
# Processing Record 49 of Set 4 | hobyo
# Processing Record 50 of Set 4 | livingston
# Processing Record 1 of Set 5 | kavali
# Processing Record 2 of Set 5 | lagoa vermelha
# Processing Record 3 of Set 5 | mount gambier
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | galveston
# Processing Record 6 of Set 5 | saskylakh
# Processing Record 7 of Set 5 | la palma
# Processing Record 8 of Set 5 | shaunavon
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 5 | cherskiy
# Processing Record 12 of Set 5 | qaanaaq
# Processing Record 13 of Set 5 | yerbogachen
# Processing Record 14 of Set 5 | port hedland
# Processing Record 15 of Set 5 | hilo
# Processing Record 16 of Set 5 | carauari
# Processing Record 17 of Set 5 | kaitangata
# Processing Record 18 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 19 of Set 5 | nicoya
# Processing Record 20 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 5 | pandan
# Processing Record 22 of Set 5 | alofi
# Processing Record 23 of Set 5 | northport
# Processing Record 24 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 25 of Set 5 | awash
# Processing Record 26 of Set 5 | leningradskiy
# Processing Record 27 of Set 5 | carutapera
# Processing Record 28 of Set 5 | pitkyaranta
# Processing Record 29 of Set 5 | ciudad bolivar
# Processing Record 30 of Set 5 | flin flon
# Processing Record 31 of Set 5 | korla
# Processing Record 32 of Set 5 | beringovskiy
# Processing Record 33 of Set 5 | lipin bor
# Processing Record 34 of Set 5 | nanortalik
# Processing Record 35 of Set 5 | dicabisagan
# Processing Record 36 of Set 5 | lahij
# Processing Record 37 of Set 5 | yinchuan
# Processing Record 38 of Set 5 | ahipara
# Processing Record 39 of Set 5 | whitecourt
# Processing Record 40 of Set 5 | hambantota
# Processing Record 41 of Set 5 | salalah
# Processing Record 42 of Set 5 | valea lunga
# City not found. Skipping...
# Processing Record 43 of Set 5 | mehamn
# Processing Record 44 of Set 5 | berdigestyakh
# Processing Record 45 of Set 5 | longyearbyen
# Processing Record 46 of Set 5 | khingansk
# Processing Record 47 of Set 5 | lebu
# Processing Record 48 of Set 5 | sakaraha
# Processing Record 49 of Set 5 | narsaq
# Processing Record 50 of Set 5 | olavarria
# Processing Record 1 of Set 6 | pangnirtung
# Processing Record 2 of Set 6 | chivay
# Processing Record 3 of Set 6 | yelizovo
# Processing Record 4 of Set 6 | kahului
# Processing Record 5 of Set 6 | mandalgovi
# Processing Record 6 of Set 6 | naze
# Processing Record 7 of Set 6 | general pico
# Processing Record 8 of Set 6 | mayya
# Processing Record 9 of Set 6 | birao
# Processing Record 10 of Set 6 | lavrentiya
# Processing Record 11 of Set 6 | chunskiy
# Processing Record 12 of Set 6 | gamba
# Processing Record 13 of Set 6 | deputatskiy
# Processing Record 14 of Set 6 | sarakhs
# Processing Record 15 of Set 6 | arman
# Processing Record 16 of Set 6 | nurota
# Processing Record 17 of Set 6 | bilma
# Processing Record 18 of Set 6 | rajula
# Processing Record 19 of Set 6 | eureka
# Processing Record 20 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 6 | kencong
# Processing Record 22 of Set 6 | iberia
# Processing Record 23 of Set 6 | ponta delgada
# Processing Record 24 of Set 6 | avera
# Processing Record 25 of Set 6 | mokhotlong
# Processing Record 26 of Set 6 | macapa
# Processing Record 27 of Set 6 | dukat
# Processing Record 28 of Set 6 | santa lucia
# Processing Record 29 of Set 6 | vidalia
# Processing Record 30 of Set 6 | torbay
# Processing Record 31 of Set 6 | iranshahr
# Processing Record 32 of Set 6 | moerai
# Processing Record 33 of Set 6 | simpang rengam
# City not found. Skipping...
# Processing Record 34 of Set 6 | burnie
# Processing Record 35 of Set 6 | guicheng
# City not found. Skipping...
# Processing Record 36 of Set 6 | tutzing
# Processing Record 37 of Set 6 | ostrovnoy
# Processing Record 38 of Set 6 | grand-santi
# Processing Record 39 of Set 6 | east millcreek
# Processing Record 40 of Set 6 | castro
# Processing Record 41 of Set 6 | alekseyevsk
# Processing Record 42 of Set 6 | san rafael
# Processing Record 43 of Set 6 | paamiut
# Processing Record 44 of Set 6 | charters towers
# Processing Record 45 of Set 6 | carnarvon
# Processing Record 46 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 6 | klaksvik
# Processing Record 48 of Set 6 | rawson
# Processing Record 49 of Set 6 | chuy
# Processing Record 50 of Set 6 | mogadishu
# Processing Record 1 of Set 7 | port blair
# Processing Record 2 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 3 of Set 7 | ilulissat
# Processing Record 4 of Set 7 | nadym
# Processing Record 5 of Set 7 | baykit
# Processing Record 6 of Set 7 | iquique
# Processing Record 7 of Set 7 | papillion
# Processing Record 8 of Set 7 | taoudenni
# Processing Record 9 of Set 7 | darnah
# Processing Record 10 of Set 7 | royan
# Processing Record 11 of Set 7 | luanda
# Processing Record 12 of Set 7 | tacoronte
# Processing Record 13 of Set 7 | kavaratti
# Processing Record 14 of Set 7 | rundu
# Processing Record 15 of Set 7 | lagunas
# Processing Record 16 of Set 7 | graaff-reinet
# Processing Record 17 of Set 7 | cabo san lucas
# Processing Record 18 of Set 7 | merauke
# Processing Record 19 of Set 7 | kangaatsiaq
# Processing Record 20 of Set 7 | dutlwe
# Processing Record 21 of Set 7 | pevek
# Processing Record 22 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 23 of Set 7 | majene
# Processing Record 24 of Set 7 | vestmanna
# Processing Record 25 of Set 7 | necochea
# Processing Record 26 of Set 7 | tomatlan
# Processing Record 27 of Set 7 | phalombe
# Processing Record 28 of Set 7 | panjwin
# City not found. Skipping...
# Processing Record 29 of Set 7 | tuatapere
# Processing Record 30 of Set 7 | bengbu
# Processing Record 31 of Set 7 | ponta do sol
# Processing Record 32 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 7 | yulara
# Processing Record 34 of Set 7 | san miguel
# Processing Record 35 of Set 7 | broken hill
# Processing Record 36 of Set 7 | qandala
# Processing Record 37 of Set 7 | atasu
# Processing Record 38 of Set 7 | tiarei
# Processing Record 39 of Set 7 | reconquista
# Processing Record 40 of Set 7 | dinard
# Processing Record 41 of Set 7 | brookhaven
# Processing Record 42 of Set 7 | chulym
# Processing Record 43 of Set 7 | ukiah
# Processing Record 44 of Set 7 | kholodnyy
# Processing Record 45 of Set 7 | kruisfontein
# Processing Record 46 of Set 7 | sur
# Processing Record 47 of Set 7 | inhambane
# Processing Record 48 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 49 of Set 7 | inirida
# Processing Record 50 of Set 7 | caraz
# Processing Record 1 of Set 8 | sanary-sur-mer
# Processing Record 2 of Set 8 | paita
# Processing Record 3 of Set 8 | sao filipe
# Processing Record 4 of Set 8 | tanda
# Processing Record 5 of Set 8 | havoysund
# Processing Record 6 of Set 8 | lazaro cardenas
# Processing Record 7 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 8 | saint george
# Processing Record 9 of Set 8 | talnakh
# Processing Record 10 of Set 8 | poum
# Processing Record 11 of Set 8 | adeje
# Processing Record 12 of Set 8 | lata
# Processing Record 13 of Set 8 | luz
# Processing Record 14 of Set 8 | pisco
# Processing Record 15 of Set 8 | launceston
# Processing Record 16 of Set 8 | gimli
# Processing Record 17 of Set 8 | luderitz
# Processing Record 18 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 20 of Set 8 | muravlenko
# Processing Record 21 of Set 8 | cap malheureux
# Processing Record 22 of Set 8 | rorvik
# Processing Record 23 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 8 | dzhebariki-khaya
# Processing Record 25 of Set 8 | boa vista
# Processing Record 26 of Set 8 | huarmey
# Processing Record 27 of Set 8 | edd
# Processing Record 28 of Set 8 | bowmore
# Processing Record 29 of Set 8 | port macquarie
# Processing Record 30 of Set 8 | sechura
# Processing Record 31 of Set 8 | itaituba
# Processing Record 32 of Set 8 | glenwood springs
# Processing Record 33 of Set 8 | susanville
# Processing Record 34 of Set 8 | kenai
# Processing Record 35 of Set 8 | roald
# Processing Record 36 of Set 8 | sao felix do xingu
# Processing Record 37 of Set 8 | alihe
# Processing Record 38 of Set 8 | aguimes
# Processing Record 39 of Set 8 | hammerfest
# Processing Record 40 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 42 of Set 8 | khopoli
# Processing Record 43 of Set 8 | vertientes
# Processing Record 44 of Set 8 | guiyang
# Processing Record 45 of Set 8 | zhigansk
# Processing Record 46 of Set 8 | chengde
# Processing Record 47 of Set 8 | mayakonda
# Processing Record 48 of Set 8 | iralaya
# Processing Record 49 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 50 of Set 8 | kyzyl-mazhalyk
# Processing Record 1 of Set 9 | yaan
# Processing Record 2 of Set 9 | berlevag
# Processing Record 3 of Set 9 | upington
# Processing Record 4 of Set 9 | tezu
# Processing Record 5 of Set 9 | buchanan
# Processing Record 6 of Set 9 | kamaishi
# Processing Record 7 of Set 9 | siavonga
# Processing Record 8 of Set 9 | huicungo
# Processing Record 9 of Set 9 | podor
# Processing Record 10 of Set 9 | fort morgan
# Processing Record 11 of Set 9 | palmares
# Processing Record 12 of Set 9 | nuevo ideal
# Processing Record 13 of Set 9 | dingle
# Processing Record 14 of Set 9 | tarija
# Processing Record 15 of Set 9 | jardim
# Processing Record 16 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 9 | sao gabriel da cachoeira
# Processing Record 19 of Set 9 | wajima
# Processing Record 20 of Set 9 | la ronge
# Processing Record 21 of Set 9 | bogale
# Processing Record 22 of Set 9 | aykhal
# Processing Record 23 of Set 9 | touros
# Processing Record 24 of Set 9 | nuevo progreso
# Processing Record 25 of Set 9 | high rock
# Processing Record 26 of Set 9 | orcopampa
# Processing Record 27 of Set 9 | udachnyy
# Processing Record 28 of Set 9 | airai
# Processing Record 29 of Set 9 | mayskiy
# Processing Record 30 of Set 9 | komsomolskiy
# Processing Record 31 of Set 9 | ha giang
# Processing Record 32 of Set 9 | ust-nera
# Processing Record 33 of Set 9 | dipkarpaz
# City not found. Skipping...
# Processing Record 34 of Set 9 | abu samrah
# Processing Record 35 of Set 9 | mirnyy
# Processing Record 36 of Set 9 | vestmannaeyjar
# Processing Record 37 of Set 9 | san patricio
# Processing Record 38 of Set 9 | praia
# Processing Record 39 of Set 9 | comodoro rivadavia
# Processing Record 40 of Set 9 | sao francisco de assis
# Processing Record 41 of Set 9 | rotterdam
# Processing Record 42 of Set 9 | shache
# Processing Record 43 of Set 9 | hami
# Processing Record 44 of Set 9 | dunn
# Processing Record 45 of Set 9 | chokwe
# Processing Record 46 of Set 9 | camiri
# Processing Record 47 of Set 9 | pangody
# Processing Record 48 of Set 9 | worland
# Processing Record 49 of Set 9 | wenatchee
# Processing Record 50 of Set 9 | kudahuvadhoo
# Processing Record 1 of Set 10 | petropavl
# Processing Record 2 of Set 10 | banjar
# Processing Record 3 of Set 10 | padang
# Processing Record 4 of Set 10 | tual
# Processing Record 5 of Set 10 | sarapul
# Processing Record 6 of Set 10 | benghazi
# Processing Record 7 of Set 10 | ngong
# Processing Record 8 of Set 10 | eydhafushi
# Processing Record 9 of Set 10 | samarai
# Processing Record 10 of Set 10 | razam
# Processing Record 11 of Set 10 | falam
# Processing Record 12 of Set 10 | kochinda
# Processing Record 13 of Set 10 | geraldton
# Processing Record 14 of Set 10 | yumbel
# Processing Record 15 of Set 10 | zalesovo
# Processing Record 16 of Set 10 | preobrazheniye
# Processing Record 17 of Set 10 | zhanaozen
# Processing Record 18 of Set 10 | puerto salgar
# Processing Record 19 of Set 10 | puerto leguizamo
# Processing Record 20 of Set 10 | wasilla
# Processing Record 21 of Set 10 | seoul
# Processing Record 22 of Set 10 | santa cruz
# Processing Record 23 of Set 10 | ak-dovurak
# Processing Record 24 of Set 10 | mundo novo
# Processing Record 25 of Set 10 | marfino
# Processing Record 26 of Set 10 | aljezur
# Processing Record 27 of Set 10 | antibes
# Processing Record 28 of Set 10 | kondinskoye
# Processing Record 29 of Set 10 | porto seguro
# Processing Record 30 of Set 10 | lyuban
# Processing Record 31 of Set 10 | matara
# Processing Record 32 of Set 10 | banda aceh
# Processing Record 33 of Set 10 | abbeville
# Processing Record 34 of Set 10 | ankara
# Processing Record 35 of Set 10 | tumbagaan
# Processing Record 36 of Set 10 | haines junction
# Processing Record 37 of Set 10 | puerto pinasco
# City not found. Skipping...
# Processing Record 38 of Set 10 | ushtobe
# Processing Record 39 of Set 10 | rosetown
# Processing Record 40 of Set 10 | asha
# Processing Record 41 of Set 10 | assiniboia
# Processing Record 42 of Set 10 | san cristobal
# Processing Record 43 of Set 10 | norman wells
# Processing Record 44 of Set 10 | puerto colombia
# Processing Record 45 of Set 10 | nea ankhialos
# Processing Record 46 of Set 10 | penapolis
# Processing Record 47 of Set 10 | buta
# Processing Record 48 of Set 10 | pitimbu
# Processing Record 49 of Set 10 | namwala
# Processing Record 50 of Set 10 | sept-iles
# Processing Record 1 of Set 11 | oneonta
# Processing Record 2 of Set 11 | wajir
# Processing Record 3 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 11 | saint-augustin
# Processing Record 6 of Set 11 | vanderhoof
# Processing Record 7 of Set 11 | asau
# Processing Record 8 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 11 | shingu
# Processing Record 10 of Set 11 | lagoa
# Processing Record 11 of Set 11 | aloleng
# Processing Record 12 of Set 11 | krasnyy chikoy
# Processing Record 13 of Set 11 | pimentel
# Processing Record 14 of Set 11 | loreto
# Processing Record 15 of Set 11 | isangel
# Processing Record 16 of Set 11 | bilibino
# Processing Record 17 of Set 11 | quatre cocos
# Processing Record 18 of Set 11 | nome
# Processing Record 19 of Set 11 | moffat
# Processing Record 20 of Set 11 | batagay
# Processing Record 21 of Set 11 | prince rupert
# Processing Record 22 of Set 11 | padilla
# Processing Record 23 of Set 11 | turukhansk
# Processing Record 24 of Set 11 | kismayo
# Processing Record 25 of Set 11 | maniitsoq
# Processing Record 26 of Set 11 | chapais
# Processing Record 27 of Set 11 | moron
# Processing Record 28 of Set 11 | charlestown
# Processing Record 29 of Set 11 | katangli
# Processing Record 30 of Set 11 | biak
# Processing Record 31 of Set 11 | hamilton
# Processing Record 32 of Set 11 | midland
# Processing Record 33 of Set 11 | lasa
# Processing Record 34 of Set 11 | kamenka
# Processing Record 35 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 11 | hovd
# Processing Record 37 of Set 11 | griffith
# Processing Record 38 of Set 11 | itoman
# Processing Record 39 of Set 11 | darlowo
# Processing Record 40 of Set 11 | vardo
# Processing Record 41 of Set 11 | cassilandia
# Processing Record 42 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 11 | phan thiet
# Processing Record 44 of Set 11 | morondava
# Processing Record 45 of Set 11 | ternate
# Processing Record 46 of Set 11 | pirovskoye
# Processing Record 47 of Set 11 | maracaju
# Processing Record 48 of Set 11 | epe
# Processing Record 49 of Set 11 | illela
# Processing Record 50 of Set 11 | radovitskiy
# Processing Record 1 of Set 12 | yar-sale
# Processing Record 2 of Set 12 | arroyo
# Processing Record 3 of Set 12 | ravar
# Processing Record 4 of Set 12 | lianran
# Processing Record 5 of Set 12 | hoquiam
# Processing Record 6 of Set 12 | kendari
# Processing Record 7 of Set 12 | polunochnoye
# Processing Record 8 of Set 12 | san policarpo
# Processing Record 9 of Set 12 | bardiyah
# Processing Record 10 of Set 12 | sri aman
# Processing Record 11 of Set 12 | port keats
# Processing Record 12 of Set 12 | fortuna
# Processing Record 13 of Set 12 | plettenberg bay
# Processing Record 14 of Set 12 | olinda
# Processing Record 15 of Set 12 | portoferraio
# Processing Record 16 of Set 12 | howard springs
# Processing Record 17 of Set 12 | liwale
# Processing Record 18 of Set 12 | chechat
# Processing Record 19 of Set 12 | conde
# Processing Record 20 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 21 of Set 12 | askiz
# Processing Record 22 of Set 12 | sungaipenuh
# Processing Record 23 of Set 12 | grindavik
# Processing Record 24 of Set 12 | fougamou
# Processing Record 25 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 26 of Set 12 | saint-georges
# Processing Record 27 of Set 12 | monte patria
# Processing Record 28 of Set 12 | nabire
# Processing Record 29 of Set 12 | namibe
# Processing Record 30 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 12 | sistranda
# Processing Record 32 of Set 12 | la paz
# Processing Record 33 of Set 12 | sorland
# Processing Record 34 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 12 | kozhva
# Processing Record 36 of Set 12 | antalaha
# Processing Record 37 of Set 12 | novobirilyussy
# Processing Record 38 of Set 12 | deming
# Processing Record 39 of Set 12 | boromo
# Processing Record 40 of Set 12 | nuevitas
# Processing Record 41 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 42 of Set 12 | guilin
# Processing Record 43 of Set 12 | wellington
# Processing Record 44 of Set 12 | wladyslawowo
# Processing Record 45 of Set 12 | ugoofaaru
# Processing Record 46 of Set 12 | labuhan
# Processing Record 47 of Set 12 | tura
# Processing Record 48 of Set 12 | pychas
# Processing Record 49 of Set 12 | dunedin
# Processing Record 50 of Set 12 | robertson
# Processing Record 1 of Set 13 | faya
# Processing Record 2 of Set 13 | colatina
# Processing Record 3 of Set 13 | batemans bay
# Processing Record 4 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 13 | san vicente
# Processing Record 6 of Set 13 | zavodoukovsk
# Processing Record 7 of Set 13 | narwar
# Processing Record 8 of Set 13 | colinas
# Processing Record 9 of Set 13 | terney
# Processing Record 10 of Set 13 | jiaojiang
# Processing Record 11 of Set 13 | yerofey pavlovich
# Processing Record 12 of Set 13 | fare
# Processing Record 13 of Set 13 | caconda
# Processing Record 14 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 15 of Set 13 | candido mendes
# Processing Record 16 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 13 | honningsvag
# Processing Record 18 of Set 13 | camacha
# Processing Record 19 of Set 13 | ullapool
# Processing Record 20 of Set 13 | yarada
# Processing Record 21 of Set 13 | goderich
# Processing Record 22 of Set 13 | port lincoln
# Processing Record 23 of Set 13 | north bend
# Processing Record 24 of Set 13 | luang prabang
# Processing Record 25 of Set 13 | henties bay
# Processing Record 26 of Set 13 | clermont
# Processing Record 27 of Set 13 | kurchum
# Processing Record 28 of Set 13 | tongsa
# City not found. Skipping...
# Processing Record 29 of Set 13 | vao
# Processing Record 30 of Set 13 | kasiri
# Processing Record 31 of Set 13 | hasaki
# Processing Record 32 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 13 | bohicon
# Processing Record 34 of Set 13 | eston
# Processing Record 35 of Set 13 | saint-pierre
# Processing Record 36 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 13 | chaihe
# Processing Record 38 of Set 13 | tureni
# Processing Record 39 of Set 13 | oranjestad
# Processing Record 40 of Set 13 | ketchikan
# Processing Record 41 of Set 13 | davila
# Processing Record 42 of Set 13 | casa nova
# Processing Record 43 of Set 13 | kandiaro
# Processing Record 44 of Set 13 | bereda
# Processing Record 45 of Set 13 | sergeyevka
# Processing Record 46 of Set 13 | ocos
# Processing Record 47 of Set 13 | philippeville
# Processing Record 48 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 49 of Set 13 | khvatovka
# Processing Record 50 of Set 13 | celestun
# Processing Record 1 of Set 14 | cascais
# Processing Record 2 of Set 14 | sao joao da barra
# Processing Record 3 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 4 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 5 of Set 14 | yuzhno-kurilsk
# Processing Record 6 of Set 14 | kupang
# Processing Record 7 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 8 of Set 14 | diamantino
# Processing Record 9 of Set 14 | sioux lookout
# Processing Record 10 of Set 14 | sobolevo
# Processing Record 11 of Set 14 | xichang
# Processing Record 12 of Set 14 | othonoi
# City not found. Skipping...
# Processing Record 13 of Set 14 | ulaangom
# Processing Record 14 of Set 14 | west wendover
# Processing Record 15 of Set 14 | adre
# Processing Record 16 of Set 14 | gdansk
# Processing Record 17 of Set 14 | zhangye
# Processing Record 18 of Set 14 | auki
# Processing Record 19 of Set 14 | palpa
# Processing Record 20 of Set 14 | vila velha
# Processing Record 21 of Set 14 | impfondo
# Processing Record 22 of Set 14 | khani
# Processing Record 23 of Set 14 | harlingen
# Processing Record 24 of Set 14 | chara
# Processing Record 25 of Set 14 | motygino
# Processing Record 26 of Set 14 | elko
# Processing Record 27 of Set 14 | dudinka
# Processing Record 28 of Set 14 | fukue
# Processing Record 29 of Set 14 | khor
# Processing Record 30 of Set 14 | kharitonovo
# Processing Record 31 of Set 14 | paine
# Processing Record 32 of Set 14 | ambon
# Processing Record 33 of Set 14 | ossora
# Processing Record 34 of Set 14 | jiaocheng
# Processing Record 35 of Set 14 | matane
# Processing Record 36 of Set 14 | igreja nova
# Processing Record 37 of Set 14 | dalnegorsk
# Processing Record 38 of Set 14 | amapa
# Processing Record 39 of Set 14 | kirkwall
# Processing Record 40 of Set 14 | arthur
# Processing Record 41 of Set 14 | byron bay
# Processing Record 42 of Set 14 | akureyri
# Processing Record 43 of Set 14 | belaya gora
# Processing Record 44 of Set 14 | bom jesus
# Processing Record 45 of Set 14 | tazovskiy
# Processing Record 46 of Set 14 | manbij
# Processing Record 47 of Set 14 | muroto
# Processing Record 48 of Set 14 | hervey bay
# Processing Record 49 of Set 14 | krasnoselkup
# Processing Record 50 of Set 14 | say
# Processing Record 1 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 2 of Set 15 | sumbe
# Processing Record 3 of Set 15 | cradock
# Processing Record 4 of Set 15 | natal
# Processing Record 5 of Set 15 | clifton
# Processing Record 6 of Set 15 | pochutla
# Processing Record 7 of Set 15 | lixourion
# Processing Record 8 of Set 15 | trincomalee
# Processing Record 9 of Set 15 | luau
# Processing Record 10 of Set 15 | skjervoy
# Processing Record 11 of Set 15 | bialogard
# Processing Record 12 of Set 15 | warrington
# Processing Record 13 of Set 15 | galegos
# Processing Record 14 of Set 15 | encruzilhada
# Processing Record 15 of Set 15 | varhaug
# Processing Record 16 of Set 15 | concordia
# Processing Record 17 of Set 15 | hede
# Processing Record 18 of Set 15 | kirillov
# Processing Record 19 of Set 15 | goure
# Processing Record 20 of Set 15 | teya
# Processing Record 21 of Set 15 | jumla
# Processing Record 22 of Set 15 | stony plain
# Processing Record 23 of Set 15 | amahai
# Processing Record 24 of Set 15 | nioro
# Processing Record 25 of Set 15 | elizabeth city
# Processing Record 26 of Set 15 | salt
# Processing Record 27 of Set 15 | jalu
# Processing Record 28 of Set 15 | sorong
# Processing Record 29 of Set 15 | itarema
# Processing Record 30 of Set 15 | tutoia
# Processing Record 31 of Set 15 | varberg
# Processing Record 32 of Set 15 | misawa
# Processing Record 33 of Set 15 | chambersburg
# Processing Record 34 of Set 15 | bud
# Processing Record 35 of Set 15 | yumen
# Processing Record 36 of Set 15 | komsomolskoye
# Processing Record 37 of Set 15 | salym
# Processing Record 38 of Set 15 | ugarcin
# City not found. Skipping...
# Processing Record 39 of Set 15 | umm lajj
# Processing Record 40 of Set 15 | scalloway
# City not found. Skipping...
# Processing Record 41 of Set 15 | hualmay
# Processing Record 42 of Set 15 | rocha
# Processing Record 43 of Set 15 | luoyang
# Processing Record 44 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 15 | dasoguz
# Processing Record 46 of Set 15 | wanning
# Processing Record 47 of Set 15 | merrill
# Processing Record 48 of Set 15 | horodok
# Processing Record 49 of Set 15 | zachary
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  avigliana      IT  45.0771    7.3986     58.48        87
# 1                     kodiak      US  57.7900 -152.4072     56.71        41
# 2  petropavlovsk-kamchatskiy      RU  53.0452  158.6483     61.39        45
# 3                    mataura      NZ -46.1927  168.8643     58.48        94
# 4                  busselton      AU -33.6500  115.3333     67.73        62
# 5                      muros      ES  42.7762   -9.0603     54.84        84
# 6                 butaritari      KI   3.0707  172.7902     82.40        74
# 7                    bubaque      GW  11.2833  -15.8333     77.02        71
# 8                     hobart      AU -42.8794  147.3294     60.06        58
# 9                     cairns      AU -16.9167  145.7667     79.11        83
#
#    Cloudiness  Wind Speed Current Description
# 0          99        0.43     overcast clouds
# 1           0       12.66           clear sky
# 2          75       11.18       broken clouds
# 3         100        0.74     overcast clouds
# 4          37        5.48    scattered clouds
# 5          92        4.81     overcast clouds
# 6          15       16.44          few clouds
# 7           3       10.87           clear sky
# 8          40       13.80    scattered clouds
# 9         100       10.36          light rain

# %%
# 8. Export the DataFrame as a CSV file, and save it as 
# WeatherPy_Database.csv in the Weather_Database folder.

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
